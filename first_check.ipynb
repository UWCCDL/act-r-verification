# %% [markdown]
# # First Inspection

# %%
import nibabel as nib
from nilearn.plotting import plot_img
import matplotlib.pyplot as plt

# %%
img = nib.load("data/sub-001/func/swasub-001_task-stroop_bold.nii")

# %%
img_data = img.get_fdata()

# %%
print(img.header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='>'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  4  79  95  68 369   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.  2.  2.  2.  0.  0.  0.  0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'spm - 3D normalized - conv(8,8,8)'
# aux_file        : b''
# qform_code      : aligned
# sform_code      : aligned
# quatern_b       : 0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# ...

# %%
mask = nib.load("ROIs/test.nii.gz")

# %%
print(mask.header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  4  79  95  68 369   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.  2.  2.  2.  1.  0.  0.  0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'5.0.11'
# aux_file        : b''
# qform_code      : aligned
# sform_code      : aligned
# quatern_b       : 0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# qoffset_x       : 78.0
# ...

# %%
from nilearn import image

# %%
d = image.index_img(img, 120)

# %%
plot_img(d)

# %%
from scipy.io import loadmat

# %%
visual_roi = loadmat("/Users/lpjiang/Downloads/analyses/ROIanalysis/rois/LManual_roi.mat")

# %%
visual_roi['roi']
# Out:
# MatlabObject([[(array([[-42, -23,  54]], dtype=int16), array([[15.625, 15.625, 16.   ]]), MatlabObject([[(array([], shape=(0, 0), dtype=uint8), MatlabObject([[(array(['/Users/Jelmer/Work/fMRI/ACTR-ROI/LManual_roi.mat'], dtype='<U48'), array(['LManual'], dtype='<U7'), array(['LManual'], dtype='<U7'), array([], dtype='<U1'), array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[0.5]]), array(['0.41'], dtype='<U4'))]],
#              dtype=[('source', 'O'), ('label', 'O'), ('descrip', 'O'), ('history', 'O'), ('spm_hold', 'O'), ('binarize', 'O'), ('roithresh', 'O'), ('cvs_version', 'O')]))]],
#              dtype=[('shape', 'O'), ('maroi', 'O')]))]],
#              dtype=[('centre', 'O'), ('widths', 'O'), ('maroi_shape', 'O')])
