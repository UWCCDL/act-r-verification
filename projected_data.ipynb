# %% [markdown]
# # PCA on each ROI

# %%
import pandas as pd

# %%
df = pd.read_csv("testing.csv")

# %%
df.head()
# Out:
#    left_manual  right_retrieval  right_imaginal  left_visual  left_imaginal  \
# 0  7246.817893      6846.642801    -7374.846268  7012.257305    7184.843218
# 1  7225.596988      6836.727162    -7371.808763  7036.246165    7167.803896
# 2  7202.322834      6849.021064    -7387.121803  7054.370763    7149.599068
# 3  7193.795965      6846.523132    -7397.410877  7069.029751    7168.634632
# 4  7202.220260      6850.801495    -7387.297244  7022.295088    7150.015655
#
#    right_manual  left_retrieval  right_visual
# 0   7422.392013     6815.978198   7153.417585
# 1   7407.707746     6808.545378   7195.055461
# 2   7391.732319     6794.056005   7225.234522
# 3   7388.881256     6822.876296   7245.635088
# 4   7362.560360     6815.136741   7236.443493

# %%
events = pd.read_csv("")

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(nrows=8, ncols=1, sharex=True)
for i, ax in enumerate(axes):
    ax.plot(df[df.columns[i]])
    ax.set_ylabel(df.columns[i])
fig.set_size_inches(20, 15)

# %%
df.columns
# Out:
# Index(['left_manual', 'right_retrieval', 'right_imaginal', 'left_visual',
#        'left_imaginal', 'right_manual', 'left_retrieval', 'right_visual'],
#       dtype='object')
